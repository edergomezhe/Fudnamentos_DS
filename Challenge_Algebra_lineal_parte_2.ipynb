# %% [markdown]
# <a href="https://colab.research.google.com/github/edergomezhe/Fudnamentos_DS/blob/main/Challenge_Algebra_lineal_parte_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %% [markdown]
# # Ejercicios
#
# Resuelve los siguientes sistemas de ecuaciones utilizando numpy

# %% [markdown]
# ![descarga.jfif](data:image/jpeg;base64,...)

# %%
M = np.array([[2,0,0],[1,2,0],[0,1,2]])
#V = [m,p,c]
R = np.array([[4],[6],[8]])
# Out:
# array([[4],
#        [6],
#        [8]])

# %%
inv = np.linalg.inv(M)
inv
# Out:
# array([[ 0.5  ,  0.   ,  0.   ],
#        [-0.25 ,  0.5  ,  0.   ],
#        [ 0.125, -0.25 ,  0.5  ]])

# %%
resultado1 = inv.dot(R)
resultado1
# Out:
# array([[2.],
#        [2.],
#        [3.]])

# %%
m, p, c = resultado1
m + (p*(c*3))
# Out:
# array([20.])

# %% [markdown]
# ![sumamarina2.jpg](data:image/jpeg;base64,...)

# %%
M2 = np.array([[1,-1,0],[0,5,0],[1,1,1]])
#V2 = [concha,caballito,estrella]
R2 = np.array([[1],[15],[14]])

# %%
inv_2 = np.linalg.inv(M2)
resultado_2 = inv_2.dot(R2)
resultado_2
# Out:
# array([[4.],
#        [3.],
#        [7.]])

# %% [markdown]
# ![WhatsApp Image 2022-04-25 at 8.06.51 PM.jpeg](data:image/jpeg;base64,...)

# %%
M3 = np.array([[1,1,0,0],[-1,1,0,0],[0,0,1,-1],[0,0,1,1]])
#V3 = [love,corazon,oso,pajaritos]
R3 = np.array([[12],[2],[3],[15]])

# %%
inv_3 = np.linalg.inv(M3)
resultado_3 = inv_3.dot(R3)
resultado_3
# Out:
# array([[5.],
#        [7.],
#        [9.],
#        [6.]])
